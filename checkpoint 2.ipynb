# %%
import os
os.chdir(r'C:\Users\vd35\OneDrive - Tesco\Documents\ESPN')

# %%
# import libraries
import urllib.request as u
from bs4 import BeautifulSoup

import csv
import itertools
import requests
proxies={"http":"uk-webproxy.edmz.tesco.org:80","https":"uk-webproxy.edmz.tesco.org:80"}

# %%
#specify url
quote_page = 'http://www.espn.co.uk/rugby/scoreboard?date=20190407'

# %%
# Set up http session
session=requests.Session()
session.proxies=proxies

# %%
response=session.get(quote_page)
html_doc = get_web_text('20190406') #response.text
soup = BeautifulSoup(html_doc,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-icon-fonts" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
#   <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <link href="http://www.espn.com/rugby/scoreboard" rel="canonical"/>
#   <title>
#    Live Rugby Scores &amp; Fixtures | ESPN
#   </title>
#   <meta content="Get live Rugby scores and performance stats for tours, leagues, and championship matches on ESPN" name="description">
#    <meta content="live rugby score, latest, update, ball by ball, match scores" name="news_keywords"/>
#    <meta content="live rugby score, latest, update, ball by ball, match scores" name="keywords"/>
#    <meta content="116656161708917" property="fb:app_id"/>
#    <meta content="ESPN.com" property="og:site_name"/>
#    <meta content="http://www.espn.com/rugby/scoreboard" property="og:url"/>
# ...

# %%
# Take out the <div> of name and get its value
name_box = soup.find('div', attrs={'id': 'events'})

# %% [raw]
# name_box

# %%
name_box
# Out:
# <div class="" data-reactid="342" id="events" style="clear:both;"><div data-reactid="343"><a data-reactid="344" href="#"><!-- react-text: 345 --> <!-- /react-text --><h2 class="date-heading js-show" data-reactid="346">Gallagher  Premiership</h2><!-- react-text: 347 --> <!-- /react-text --></a><!-- react-text: 348 --><!-- /react-text --><article class="scoreboard rugby js-show" data-reactid="349"><div class="scoreboard-top no-tabs" data-reactid="350"><a class="mobileScoreboardLink" data-reactid="351" data-route="false" href="/rugby/match?gameId=293504&amp;league=267979"></a><div class="scoreboard-wrapper game-strip-scoreboard" data-reactid="352"><div data-reactid="353"><header class="game-strip rugby team-b-winner post" data-reactid="354"><!-- react-text: 355 --><!-- /react-text --><a class="competitors" data-reactid="356" data-route="false" href="/rugby/match?gameId=293504&amp;league=267979"><div class="team team-a possession" data-reactid="357"><div class="team__content" data-reactid
# ...

# %%
teama_boxes = soup.findAll('div', attrs={'class':'team team-a possession'}) #.find('span', attrs={"class","short-name"})

# %%
teamb_boxes = soup.findAll('div', attrs={'class':'team team-b possession'})

# %%
def get_team_data():
    data=[]
    home_team_boxes = soup.findAll('div', attrs={'class':'team team-a possession'})
    away_team_boxes = soup.findAll('div', attrs={'class':'team team-b possession'})
    
    for i in range(len(home_team_boxes)): 
        item = {}
        home_team_tag = home_team_boxes[i]
        away_team_tag = away_team_boxes[i]
        item["home_team"] = home_team_tag.find('span', attrs={"class","short-name"}).text
        item["away_team"] = away_team_tag.find('span', attrs={"class","short-name"}).text
        item["home_score"] = home_team_tag.find('div', attrs={"class","score icon-font-after"}).text
        item["away_score"] = away_team_tag.find('div', attrs={"class","score icon-font-before"}).text
        data.append(item)
    
    return data

# %%
dir.len
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-515-ce8959703467> in <module>
# ----> 1 dir.len
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'len'

# %%
def get_event_occurences():
    data=[]
    tournament_boxes = soup.findAll('div', attrs={'id':'events'})

    for i in range(len(tournament_boxes)):
        item = {}
        tournament_tag = tournament_boxes[i]
        item["tournament"] = tournament_tag.find('h2', attrs={'class':'date-heading js-show'}).text
        item["occurences"] = len(tournament_tag.find('div', attrs={'class':'scoreboard-top no-tabs'}))
        data.append(item)
        
    return data

# %%
def get_web_text(date_id):
    """

    :param date_id: Like 20190407
    :return: text of file
    """
    
    filename = "espn_rugby_{}.html".format(date_id)
    return open(filename).read()
  
"""
def main():

    web_text = get_web_text('20190407')
    print(web_text)


if __name__ == '__main__':
    main()
"""
# Out:
# "\ndef main():\n\n    web_text = get_web_text('20190407')\n    print(web_text)\n\n\nif __name__ == '__main__':\n    main()\n"

# %%
get_web_text('20190407')
# Out:
# '\n\t<!DOCTYPE html>\n\t<html class="no-icon-fonts" lang="en">\n\t<head>\n\t\t<meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n<meta http-equiv="x-ua-compatible" content="IE=edge,chrome=1" />\n<meta name="viewport" content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n<link rel="canonical" href="http://www.espn.com/rugby/scoreboard" />\n<title>Live Rugby Scores & Fixtures | ESPN</title>\n<meta name="description" content="Get live Rugby scores and performance stats for tours, leagues, and championship matches on ESPN" />\n<meta name="news_keywords" content="live rugby score, latest, update, ball by ball, match scores" />\n<meta name="keywords" content="live rugby score, latest, update, ball by ball, match scores" />\n<meta property="fb:app_id" content="116656161708917" />\n<meta property="og:site_name" content="ESPN.com" />\n<meta property="og:url" content="http://www.espn.com/rugby/scoreboard" />\n<meta property="og:title" content="Live Rugby Scores
# ...

# %%
#children = tournament_boxes.findChildren("div", recursive = False)

def get_match_data():
    data = []
    tournament_boxes = soup.findAll('div', attrs={'id':'events'})[0].children

    for tournament_tag in tournament_boxes:
        if tournament_tag.name == 'div':

            home_team_boxes = tournament_tag.findAll('div', attrs={'class':'team team-a possession'})
            away_team_boxes = tournament_tag.findAll('div', attrs={'class':'team team-b possession'})
            away_tries_scored = tournament_tag.findAll('div', attrs={"class":"team away"})
            home_tries_scored = tournament_tag.findAll('div', attrs={"class":"team home"})
            for i in range(len(home_tries_scored)): 
               
                    item = {}
                    home_team_tag = home_team_boxes[i]
                    away_team_tag = away_team_boxes[i]
                    home_tries_tag = home_tries_scored[i]
                    away_tries_tag = away_tries_scored[i]              
                    
                    item["tournament"] = tournament_tag.find('h2', attrs={"class","date-heading js-show"}).text
                    item["home_team"] = home_team_tag.find('span', attrs={"class","short-name"}).text
                    item["away_team"] = away_team_tag.find('span', attrs={"class","short-name"}).text
                    item["home_score"] = home_team_tag.find('div', attrs={"class","score icon-font-after"}).text
                    item["away_score"] = away_team_tag.find('div', attrs={"class","score icon-font-before"}).text
                    home_scorers = home_tries_tag.find('ul', attrs={
                        "class": "goal icon-font-before icon-rugby-solid-before icon-rugby-solid"})
                    if not home_scorers:
                        item["home_tries"] = 0
                    else:
                        item["home_tries"] = len(list(home_scorers))

                    away_scorers = away_tries_tag.find('ul', attrs={"class": "goal icon-font-before icon-rugby-solid-before icon-rugby-solid"})
                    if not away_scorers:
                        item["away_tries"] = 0
                    else:
                        item["away_tries"] = len(list(away_scorers))

    return data

#tries_scored = soup.find('ul', attrs={"class":"goal icon-font-before icon-rugby-solid-before icon-rugby-solid"})

#len(list(tries_scored))


 #  for child in tournament_tag.descendants:
   #     print(child)

#for i in children:
 #   print (i).text

# %%
get_match_data()
# Out:
# []

# %%
import pandas as pd
df = pd.DataFrame.from_records(get_match_data())

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import itertools
lst = range(1,5)
list(itertools.chain.from_iterable(itertools.repeat(x, 3)) for x in lst)

# %%
home_team_boxes = soup.findAll('div', attrs={'class':'team team-a possession'})

#result = list(range(len(home_team_boxes)))
#for i, item in enumerate(home_team_boxes):
#    print(i, item)
#print(result)
# Out:
# 0 <div class="team team-a possession" data-reactid="357"><div class="team__content" data-reactid="358"><div class="team-container" data-reactid="359"><div class="team-info" data-reactid="360"><div class="team-info-wrapper" data-reactid="361"><!-- react-text: 362 --><!-- /react-text --><span class="team-name" data-reactid="363"><!-- react-text: 364 --><!-- /react-text --><span class="short-name" data-reactid="365">Northampton Saints</span><span class="abbrev" data-reactid="366">NTHMP</span></span></div><!-- react-text: 367 --><!-- /react-text --></div><div class="team-info-logo" data-reactid="368"><div class="logo" data-reactid="369"><picture data-reactid="370"><source data-reactid="371" srcset="https://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25907.png&amp;h=35&amp;w=35"/><img class="team-logo imageLoaded" data-default-src="https://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25907.png&amp;h=35&amp;w=35" data-reactid="372" src="https://a1.espncdn.com/c
# ...

# %%
def get_tournament_data():
    data=[]
    tournament_boxes = soup.findAll('div', attrs={'id':'events'})
    
    for i in tournament_boxes: 
        item = {}
        tournament_tag = tournament_boxes[i]
        item["tournament"] = tournament_tag.find('h2', attrs={"class","date-heading js-show"}).text
    
        data.append(item)
    
    return data

# %%
import pandas as pd
df = pd.DataFrame.from_records(get_team_data())

# %%
df.head()
# Out:
#   away_score         away_team home_score           home_team
# 0         40  Gloucester Rugby         31  Northampton Saints
# 1         31         Racing 92         31   Clermont Auvergne
# 2         27              Lyon         24                 Pau
# 3         18           Dragons         18      Southern Kings
# 4                          UZB                       Pakistan

# %%
tournament_box = soup.findAll('h2', attrs={'class':'date-heading js-show'})

# %%
tournament_box
# Out:
# [<h2 class="date-heading js-show" data-reactid="346">Gallagher  Premiership</h2>,
#  <h2 class="date-heading js-show" data-reactid="459">Top 14 Orange</h2>,
#  <h2 class="date-heading js-show" data-reactid="681">Guinness PRO14</h2>,
#  <h2 class="date-heading js-show" data-reactid="783">Asian 5 Nations - Divisio</h2>,
#  <h2 class="date-heading js-show" data-reactid="849">Major League Rugby</h2>]

# %%
for i in tournament_box:
    print(i.text)
    #tag = i.find('h2', attrs={'class':'date-heading js-show'})
    #if tag:
     #   tournament = tag.text
      #  print(tournament)
# Out:
# Gallagher  Premiership
# Top 14 Orange
# Guinness PRO14
# Asian 5 Nations - Divisio
# Major League Rugby

# %%
event_boxes = soup.findAll('div')

# %%
for i in range(len(tournament_box)):

    repeat(i,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-371-65a5c1e1b896> in <module>
#       1 for i in range(len(tournament_box)):
#       2
# ----> 3     repeat(i,3)
#       4
#
# NameError: name 'repeat' is not defined

# %%
len(event_boxes)
# Out:
# 308

# %%
   # tournament_boxes = soup.findAll('div', attrs={'id':'events'})[0].children

    #for tournament_tag in tournament_boxes:
     #   if tournament_tag.name == 'div':


tries_scored = soup.find('ul', attrs={"class":"goal icon-font-before icon-rugby-solid-before icon-rugby-solid"})

#len(list(tries_scored))

# %%
len(list(tries_scored))
# Out:
# 5
